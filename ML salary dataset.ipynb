# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#load the dataset
salary_data=pd.read_csv("E:\coe projects\Salary datasets .csv") 
salary_data.head()
# Out:
#    years_experience  salary
# 0               3.7   32610
# 1               9.5   61447
# 2               7.3   51729
# 3               6.0   42857
# 4               1.6   30797

# %%
df=salary_data

# %%
df.sample(10)
# Out:
#      years_experience  salary
# 95                4.9   38090
# 96                5.2   46696
# 196               7.3   48695
# 57                2.0   38558
# 7                 8.7   59120
# 11                9.7   59188
# 41                5.0   36763
# 61                2.7   32104
# 136               5.2   42243
# 22                2.9   31880

# %%
#DIVIDE DATA INTO X AND Y

X=df["years_experience"]
Y=df["salary"]

# %%
#TRAIN AND TEST SPLITTING

from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
Y_train.shape
# Out:
# (160,)

# %%
X_train=X_train.values.reshape(-1,1)

# %%
#Train model Linear Regresion
from sklearn.linear_model import LinearRegression
#loading the model
LR=LinearRegression()
# training model on X_train and Y_tain 
model=LR.fit(X_train,Y_train)

# %%
#prediction X_test
Y_pred=model.predict(X_test.values.reshape(-1,1))
Y_pred
# Out:
# array([40247.41443883, 26199.37750596, 45685.3642193 , 28918.35239619,
#        18495.61531696, 57467.58874365, 62905.53852412, 48857.50159124,
#        47498.01414612, 47951.17662783, 24386.72757913, 59733.40115218,
#        56108.10129853, 34356.30217666, 55201.77633512, 35715.78962178,
#        22120.9151706 , 24386.72757913, 32996.81473154, 21214.59020719,
#        28465.18991448, 31637.32728642, 20308.26524378, 43419.55181077,
#        42513.22684736, 35715.78962178, 32090.48976813, 54295.45137171,
#        37528.4395486 , 23480.40261572, 50216.98903636, 37528.4395486 ,
#        59733.40115218, 51123.31399977, 59280.23867047, 59280.23867047,
#        32543.65224984, 49763.82655465, 22120.9151706 , 52935.96392659])

# %%
data=pd.DataFrame({"Actual":Y_test,"Predicted":Y_pred,"difference":Y_test-Y_pred})
data.head(10)
# Out:
#      Actual     Predicted   difference
# 95    38090  40247.414439 -2157.414439
# 15    31790  26199.377506  5590.622494
# 30    42237  45685.364219 -3448.364219
# 158   28147  28918.352396  -771.352396
# 128   18791  18495.615317   295.384683
# 115   52860  57467.588744 -4607.588744
# 69    56948  62905.538524 -5957.538524
# 170   46145  48857.501591 -2712.501591
# 174   50724  47498.014146  3225.985854
# 45    48161  47951.176628   209.823372

# %%
from sklearn.metrics import mean_squared_error,r2_score
R2=r2_score(Y_test,Y_pred)

MSE=mean_squared_error(Y_test,Y_pred)
print(R2*100)
print(MSE)
# Out:
# 94.14826849819674
# 9762990.417736227

# %%
sns.histplot(df['salary'],kde=True)
plt.title('Histogram of salary')
plt.show()

# %%
sns.histplot(df['years_experience'],kde=True)
plt.title('Histogram of years_experience')
plt.show()

# %%
sns.scatterplot(x='years_experience', y='salary', data=df)
plt.show()

# %%
sns.boxplot(x='years_experience', y='salary', data=df)
plt.show()

# %%
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.pairplot(data)
plt.show()

# %%
sns.pairplot(df)

# %%
sns.barplot(x='years_experience',y='salary',data=df)
plt.show()

# %%
sns.violinplot(x='years_experience',y='salary',data=df)
plt.show()

# %%
# Import Pandas
import pandas as pd
# Creating DataFrame
data = {'A': [1, 2, 3], 'B': [4, 5, 6]}
df = pd.DataFrame(data)
# Display the DataFrame
print(df)

# Viewing Data
# First 5 rows
print(df.head())
# Last 5 rows
print(df.tail())
# DataFrame information
print(df.info())
# Summary statistics
print(df.describe())
# Dimensions of the DataFrame
print(df.shape)
# Column names
print(df.columns)
# Selecting Data
# Select a single column
print(df['A'])
# Select multiple columns
print(df[['A', 'B']])# Select rows by label
print(df.loc[0])
# Select rows by position
print(df.iloc[0])
# Conditional selection
print(df[df['A'] > 1])
# Modifying Data
# Adding a new column
df['C'] = df['A'] + df['B']
# Renaming columns
df.rename(columns={'A': 'Alpha', 'B': 'Beta'}, inplace=True)
# Dropping columns
df.drop(['C'], axis=1, inplace=True)
# Dropping rows
df.drop([0], axis=0, inplace=True)
# Replacing values
df.replace(1, 10, inplace=True)
# Sorting values
df.sort_values(by='Alpha', ascending=True, inplace=True)
# Handling Missing Data
# Checking for missing data
print(df.isnull())
print(df.isnull().sum())
# Dropping missing data
df.dropna(inplace=True)
# Filling missing data
df.fillna(0, inplace=True)
# Grouping and Aggregation
# Grouping data
grouped = df.groupby('Beta')
# Aggregating data
print(grouped.sum())
print(grouped.mean())
# Merging and Joining
# Concatenating DataFrames
df_concat = pd.concat([df, df])
# Merging DataFrames
df_merge = pd.merge(df, df, on='Alpha')
# Joining DataFrames
df1 = pd.DataFrame({'key': ['A', 'B', 'C'], 'val1': [1, 2, 3]})
df2 = pd.DataFrame({'key': ['A', 'B', 'D'], 'val2': [4, 5, 6]})
df_join = df1.set_index('key').join(df2.set_index('key'), how='inner')
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
# dtypes: int64(2)
# memory usage: 180.0 bytes
# None
#          A    B
# count  3.0  3.0
# mean   2.0  5.0
# std    1.0  1.0
# min    1.0  4.0
# 25%    1.5  4.5
# 50%    2.0  5.0
# 75%    2.5  5.5
# max    3.0  6.0
# (3, 2)
# Index(['A', 'B'], dtype='object')
# 0    1
# 1    2
# 2    3
# Name: A, dtype: int64
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
# A    1
# B    4
# Name: 0, dtype: int64
# A    1
# B    4
# Name: 0, dtype: int64
#    A  B
# 1  2  5
# 2  3  6
#    Alpha   Beta
# 1  False  False
# 2  False  False
# Alpha    0
# Beta     0
# dtype: int64
#       Alpha
# Beta
# 5         2
# 6         3
#       Alpha
# ...
